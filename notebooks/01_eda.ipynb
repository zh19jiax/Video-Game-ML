# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Read the CSV file
df = pd.read_csv('../data/video_game_reviews.csv')

# Select only numeric columns
numeric_columns = df.select_dtypes(include=['int64', 'float64']).columns

# Create correlation matrix
correlation_matrix = df[numeric_columns].corr()

# Create a heatmap visualization
plt.figure(figsize=(12, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', vmin=-1, vmax=1, center=0)
plt.title('Correlation Matrix of Numeric Variables')
plt.tight_layout()
plt.show()

# %%
# Let's see what columns we have in the dataset
print("Column names in the dataset:")
print(df.columns.tolist())

# %%
# Analyze User Rating statistics
print("User Rating Statistics:")
print("-" * 20)
print(f"Minimum Rating: {df['User Rating'].min()}")
print(f"Maximum Rating: {df['User Rating'].max()}")
print(f"Average Rating: {df['User Rating'].mean():.2f}")
print(f"\nRating Distribution:")
print(df['User Rating'].value_counts().sort_index())

# Create a histogram to visualize the distribution
plt.figure(figsize=(10, 6))
plt.hist(df['User Rating'], bins=20, edgecolor='black')
plt.title('Distribution of User Ratings')
plt.xlabel('Rating')
plt.ylabel('Frequency')
plt.grid(True, alpha=0.3)
plt.show()
